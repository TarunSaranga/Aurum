# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, auc, f1_score

# %%
df = pd.read_csv("JS_Indicators.csv")

# %%
df.head()
# Out:
#                     DateTime     open     high  ...      rsi36      macd   macdsig
# 0  2015-02-03 09:15:00+05:30  1575.00  1581.70  ...  67.809765  4.200250  3.644825
# 1  2015-02-03 09:16:00+05:30  1578.90  1581.90  ...  69.057796  4.762186  3.868297
# 2  2015-02-03 09:17:00+05:30  1580.00  1580.00  ...  61.418445  4.625673  4.019772
# 3  2015-02-03 09:18:00+05:30  1574.45  1577.95  ...  63.055007  4.669423  4.149702
# 4  2015-02-03 09:19:00+05:30  1577.00  1577.00  ...  61.528525  4.534818  4.226725
#
# [5 rows x 27 columns]

# %%
df["close_1"] = df.close.shift(1)
df["close_2"] = df.close.shift(2)
df["close_3"] = df.close.shift(3)
df["close_4"] = df.close.shift(4)
df["close_5"] = df.close.shift(5)
df["close_6"] = df.close.shift(6)
df["close_7"] = df.close.shift(7)
df["close_8"] = df.close.shift(8)
df["close_9"] = df.close.shift(9)
df["close_10"] = df.close.shift(10)
df["close_11"] = df.close.shift(11)
df["close_12"] = df.close.shift(12)
df["close_13"] = df.close.shift(13)
df["close_14"] = df.close.shift(14)

# %%
df = df[15:-15]

# %%
df["label"] = df.close < (df.close.shift(-1))# - df.close*0.001)

# %%
df.label.replace(True, 1,inplace=True)
df.label.replace(False, 0, inplace=True)

# %%
X = df.drop(["label","DateTime"],axis=1)
y = df.label

X1 = df[["close","close_1","close_2","close_3","close_4","close_5","close_6","close_7","close_8","close_9","close_10","close_11","close_12","close_13","close_14",]]
y1 = df.label

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8, shuffle=False)
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, train_size=0.8, shuffle=False)

# %%
rf = RandomForestClassifier()
rf1 = RandomForestClassifier()

# %%
#rf.fit(X_train, y_train)
rf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf.score(X_train,y_train)
# Out:
# 0.9826018568249827

# %%
rf.score(X_test, y_test)
# Out:
# 0.5423923885521369

# %%
y_pred = rf.predict(X_test)

# %%
f1_score(y_test,y_pred)
# Out:
# 0.4032419451671002
